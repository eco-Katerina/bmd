# %%
import seaborn as sns
import pandas as pd

# %%
data = pd.DataFrame({
    "n":[1,2,3,4,5,6,7],
    "Група1":[50, 20, 40, 35, 75, 85, 25],
    "Група2": [65, 10, 35, 54, 60, 26, 75],
    "Група3": [44, 36, 65, 59, 80, 49, 50]
})
n = data.shape[0]

data
# Out:
#    n  Група1  Група2  Група3
# 0  1      50      65      44
# 1  2      20      10      36
# 2  3      40      35      65
# 3  4      35      54      59
# 4  5      75      60      80
# 5  6      85      26      49
# 6  7      25      75      50

# %% [markdown]
# 1. Розрахувати та вивести у вигляді таблиці статистичні характиристики даних (середні та стандартні відхилення для кожної з груп).

# %%
data_data = pd.DataFrame({
    "Название": ["Среднее отклонение","Стандартное отклонение"],
    "Група1":[sum(data.iloc[:,1]/n), data.iloc[:,1].std()],
    "Група2":[sum(data.iloc[:,2]/n), data.iloc[:,2].std()],
    "Група3": [sum(data.iloc[:,3]/n), data.iloc[:,3].std()]
})
data_data
# Out:
#                  Название     Група1     Група2     Група3
# 0      Среднее отклонение  47.142857  46.428571  54.714286
# 1  Стандартное отклонение  24.640269  23.372756  14.625483

# %% [markdown]
# 2. Побудувати графік розкиду в групах.

# %%
sns.boxplot(data=data, palette='rainbow', orient='h')

# %%
data.loc[data.shape[0]+1] = ["Сума: ",sum(data.iloc[:,1]), sum(data.iloc[:,2]), sum(data.iloc[:,3])]
data.loc[data.shape[0]+1] = ["Середні: ", round(data.iloc[n,1]/n, 2), round(data.iloc[n,2]/n, 2), round(data.iloc[n,3]/n, 2)]
n = data.shape[0]
data
# Out:
#            n  Група1  Група2  Група3
# 0          1   50.00   65.00   44.00
# 1          2   20.00   10.00   36.00
# 2          3   40.00   35.00   65.00
# 3          4   35.00   54.00   59.00
# 4          5   75.00   60.00   80.00
# 5          6   85.00   26.00   49.00
# 6          7   25.00   75.00   50.00
# 8     Сума:   330.00  325.00  383.00
# 9  Середні:    47.14   46.43   54.71

# %%
summa = sum(data.iloc[n-2, 1:])
print("Загальна сума: ", summa)
data
# Out:
# Загальна сума:  1038.0
#            n  Група1  Група2  Група3
# 0          1   50.00   65.00   44.00
# 1          2   20.00   10.00   36.00
# 2          3   40.00   35.00   65.00
# 3          4   35.00   54.00   59.00
# 4          5   75.00   60.00   80.00
# 5          6   85.00   26.00   49.00
# 6          7   25.00   75.00   50.00
# 8     Сума:   330.00  325.00  383.00
# 9  Середні:    47.14   46.43   54.71

# %% [markdown]
# 3. Побудувати функцію, що реалізовує однофакторний дисперсійний аналіз.

# %%
def dispers(data, n):    
    first_sum = data.iloc[n-2,1]
    second_sum = data.iloc[n-2,2]
    third_sum = data.iloc[n-2, 3]
    Tc2 = first_sum**2 + second_sum**2 + third_sum**2
    c = data.shape[1]-1
    n = data.shape[0]-2
    N = n*c
    sum2 = sum(data.iloc[n, 1:])**2
    constanta = sum2/N
    xi2 = 0
    for i in range(0, n):
        xi2 += data.iloc[i, 1]**2
    for i in range(0, n):
        xi2 += data.iloc[i, 2]**2
    for i in range(0, n):
        xi2 += data.iloc[i, 3]**2
    
    SSfact = Tc2/n - constanta
    print("SSфактичне:", SSfact)
    SSzag = xi2 - sum2/N
    print("SSзагальне:", SSzag)
    SSvip = SSzag - SSfact
    print("SSвипадкове:", SSvip)
    
    dfact = c - 1
    print("\ndфактичне:", dfact)
    dzag = N - 1
    print("dзагальне:", dzag)
    dvip = dzag - dfact
    print("dвипадкове:", dvip)
    
    MSfact = SSfact/dfact
    print("\nMSфактичне:", MSfact)
    MSvip = SSvip/dvip
    print("MSвипадкове:", MSvip)
    
    Femp = MSfact/MSvip
    print("\nFемпіричне", Femp)
    Fcrit = pd.read_excel("Таблиця критичних значень для критерію Фішера.xlsx").iloc[dzag-2, dfact]
    if (Fcrit >= Femp):
        print("Рівність середніх підтверджена", Fcrit, ">", Femp)
    else:
        print("Рівність середніх не підтверджена", Fcrit, "<", Femp)
    
    data_end = pd.DataFrame({
        "Назва":["Фактичне", "Випадкове", "Загальне"],
        "SS":[SSfact, SSvip, SSzag],
        "d":[dfact, dvip, dzag],
        "MS":[MSfact, MSvip, None]
    })
    return data_end

# %% [markdown]
# 4.Вивести результати розрахунку кожного з етапів вказаних вище у вигляді таблиці.
#
# 5.Перевірити результат роботи функції на реальних або сгенерованих даних. Зробити висновок

# %%
dispers(data, n)
# Out:
# SSфактичне: 295.14285714285506
# SSзагальне: 8499.142857142855
# SSвипадкове: 8204.0
#
# dфактичне: 2
# dзагальне: 20
# dвипадкове: 18
#
# MSфактичне: 147.57142857142753
# MSвипадкове: 455.77777777777777
#
# Fемпіричне 0.32377934108796874
# Рівність середніх підтверджена 3.5 > 0.32377934108796874
#        Назва           SS   d          MS
# 0   Фактичне   295.142857   2  147.571429
# 1  Випадкове  8204.000000  18  455.777778
# 2   Загальне  8499.142857  20         NaN
